# %%
import numpy as np
import plotly.graph_objects as go
from scipy.stats import multivariate_normal

# Mean and covariance matrix
mean = [0, 0]
cov = [[1, 0], [0, 1]]

# Create a meshgrid
x, y = np.meshgrid(np.linspace(-5, 5, 100), np.linspace(-5, 5, 100))
pos = np.dstack((x, y))

# Create a bivariate normal distribution object
rv = multivariate_normal(mean, cov)

# Evaluate the PDF at the points in the meshgrid
z = rv.pdf(pos)

# Create a 3D surface plot using Plotly
fig = go.Figure(data=[go.Surface(z=z, x=x, y=y, colorscale='viridis')])
fig.update_layout(title='Bivariate Normal Distribution',
                  scene=dict(xaxis_title='X',
                             yaxis_title='Y',
                             zaxis_title='Probability Density'))

# Show the interactive plot
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 27
#      21 fig.update_layout(title='Bivariate Normal Distribution',
#      22                   scene=dict(xaxis_title='X',
#      23                              yaxis_title='Y',
#      24                              zaxis_title='Probability Density'))
#      26 # Show the interactive plot
# ---> 27 fig.show()
#
# File ~/Documents/notebooks/.venv/lib/python3.11/site-packages/plotly/basedatatypes.py:3409, in BaseFigure.show(self, *args, **kwargs)
#    3376 """
#    3377 Show a figure using either the default renderer(s) or the renderer(s)
#    3378 specified by the renderer argument
#    (...)
#    3405 None
#    3406 """
#    3407 import plotly.io as pio
# -> 3409 return pio.show(self, *args, **kwargs)
#
# File ~/Documents/notebooks/.venv/lib/python3.11/site-packages/plotly/io/_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
#     393         )
#     395     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 396         raise ValueError(
#     397             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     398         )
#     400     ipython_display.display(bundle, raw=True)
#     402 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
