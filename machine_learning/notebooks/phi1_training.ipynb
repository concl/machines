# %%
import torch
import transformers
import os

# %%
os.environ['TRANSFORMERS_CACHE'] = "/home/no/projects/machines/.cache"
os.environ['TRANSFORMERS_CACHE']
# Out:
# '/home/no/projects/machines/.cache'

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer



model = AutoModelForCausalLM.from_pretrained("microsoft/phi-1_5", trust_remote_code=True, torch_dtype=torch.float16).to("cuda")
tokenizer = AutoTokenizer.from_pretrained("microsoft/phi-1_5", trust_remote_code=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 5
#       1 from transformers import AutoModelForCausalLM, AutoTokenizer
# ----> 5 model = AutoModelForCausalLM.from_pretrained("microsoft/phi-1_5", trust_remote_code=True, torch_dtype=torch.float16).to("cuda")
#       6 tokenizer = AutoTokenizer.from_pretrained("microsoft/phi-1_5", trust_remote_code=True)
#
# File ~/projects/machines/.venv/lib/python3.11/site-packages/transformers/models/auto/auto_factory.py:553, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     551 if has_remote_code and trust_remote_code:
#     552     class_ref = config.auto_map[cls.__name__]
# --> 553     model_class = get_class_from_dynamic_module(
#     554         class_ref, pretrained_model_name_or_path, code_revision=code_revision, **hub_kwargs, **kwargs
#     555     )
# ...
