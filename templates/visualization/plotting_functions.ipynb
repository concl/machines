# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
    return x**2 + 4 * np.cos(x)

x = np.linspace(1, 2, 100)
y = f(x)

fig, ax = plt.subplots()
ax.grid(color="#88888888")
ax.plot(x, y, color="red")
plt.show()
