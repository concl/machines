# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def quadratic_function(x):
    Q = np.array([[3, 1], [1, 2]])
    b = np.array([1, 1])
    c = 0
    
    return 0.5 * x.T @ Q @ x + b.T @ x + c

x, y = np.meshgrid(np.linspace(-5, 5, 100), np.linspace(-5, 5, 100), indexing='xy')

coordinates = np.concatenate([x, y, axis=1])

coordinates
