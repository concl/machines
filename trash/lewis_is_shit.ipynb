# %%
import numpy as np
from math import *

(450 * cos(radians(38)) - 125) / 96
# Out:
# 2.391717074198176

# %%
96 / 9.8
# Out:
# 9.795918367346937

# %%
(450 * cos(radians(38)) - 125) / 9.8
# Out:
# 23.42906521663519

# %%
(220-0.37*539) / 55
# Out:
# 0.3739999999999999

# %%
-.132/ 1.2
# Out:
# -0.11000000000000001
